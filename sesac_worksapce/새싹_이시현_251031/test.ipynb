# %%
"Hi"
# Out:
# 'Hi'

# %%
name = "이시현"
age = 26

# %%
123
# Out:
# 123

# %%
var1 = "덩덕"
var2 = "쿵덕"

re1 = var1 + var2
re2 = var2 * 2
re3 = (re1+re2) * 2

print(re1)
print(re2)
print(re3)
# Out:
# 덩덕쿵덕
# 쿵덕쿵덕
# 덩덕쿵덕쿵덕쿵덕덩덕쿵덕쿵덕쿵덕
